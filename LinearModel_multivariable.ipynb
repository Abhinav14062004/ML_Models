# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhinav14062004/ML_Models/blob/main/LinearModel_multivariable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt


from google.colab import drive
drive.mount('/content/drive')


df= pd.read_csv('/content/drive/MyDrive/ML_CSV_files/multi_variable/multivariable.csv')
df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %%
import math
df.bedrooms = df.bedrooms.fillna(df.bedrooms.median())
df.bedrooms
# Out:
# 0    3.0
# 1    4.0
# 2    3.5
# 3    3.0
# 4    5.0
# Name: bedrooms, dtype: float64

# %%
model = linear_model.LinearRegression()
model.fit(df.drop("price",axis="columns"),df.price)
# Out:
# LinearRegression()

# %%
model.predict([[3300,3,14]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([761502.70758123])

# %%
x=model.predict(df.drop("price",axis="columns"))

# %%
df["prices"]=x
df
# Out:
#    area  bedrooms  age   price         prices
# 0  2600       3.0   20  550000  536965.939413
# 1  3000       4.0   15  565000  571109.715900
# 2  3200       3.5   18  610000  626292.575734
# 3  3600       3.0   30  595000  592759.770837
# 4  4000       5.0    8  760000  752871.998116

# %%
df.to_csv("/content/drive/MyDrive/ML_CSV_files/multi_variable/result.csv")
