# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhinav14062004/ML_Models/blob/main/LinearModel_multivariable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt


from google.colab import drive
drive.mount('/content/drive')


df= pd.read_csv('/content/drive/MyDrive/ML_CSV_files/multi_variable/multivariable_exercise.csv')
df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    experience  test_score  interview_score  salary
# 0         NaN         8.0                9   50000
# 1         NaN         8.0                6   45000
# 2         5.0         6.0                7   60000
# 3         2.0        10.0               10   65000
# 4         7.0         9.0                6   70000
# 5         3.0         7.0               10   62000
# 6        10.0         NaN                7   72000
# 7        11.0         7.0                8   80000

# %%
import math
df.experience = df.experience.fillna(0)
df.experience
# Out:
# 0     0.0
# 1     0.0
# 2     5.0
# 3     2.0
# 4     7.0
# 5     3.0
# 6    10.0
# 7    11.0
# Name: experience, dtype: float64

# %%
import math
df.test_score = df.test_score.fillna(0)
df.test_score
# Out:
# 0     8.0
# 1     8.0
# 2     6.0
# 3    10.0
# 4     9.0
# 5     7.0
# 6     0.0
# 7     7.0
# Name: test_score, dtype: float64

# %%
model = linear_model.LinearRegression()
model.fit(df.drop("salary",axis="columns"),df.salary)
# Out:
# LinearRegression()

# %%
model.predict([[0,7,5]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([42414.46421462])

# %%
y = model.predict(df.drop("salary", axis="columns"))

# %%
df["salary"]=y
df
# Out:
#    experience  test_score  interview_score        salary
# 0         0.0         8.0                9  51888.203228
# 1         0.0         8.0                6  45532.738186
# 2         5.0         6.0                7  61040.976327
# 3         2.0        10.0               10  62161.991241
# 4         7.0         9.0                6  68077.573270
# 5         3.0         7.0               10  62240.498576
# 6        10.0         0.0                7  70431.583622
# 7        11.0         7.0                8  82626.435550

# %%
df.to_csv("/content/drive/MyDrive/ML_CSV_files/multi_variable/multivariable_exercise_result.csv")
